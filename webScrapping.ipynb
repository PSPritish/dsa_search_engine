# %% [markdown]
# ### Using api for leetcode

# %%
import requests
from bs4 import BeautifulSoup
import psycopg2

# %%
import requests
import json

url = "https://leetcode.com/graphql"
headers = {
    "Content-Type": "application/json",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
}
# Define the GraphQL query for fetching problems
problem_list_query = '''
query problemsetQuestionList($limit: Int!, $skip: Int!) {
    problemsetQuestionListV2(
        limit: $limit
        skip: $skip
    ) {
        questions {
            titleSlug
            title
            difficulty
        }
    }
}
'''

# Reusing existing variables (url and headers)
all_problems = []
page_size = 100  # Fetch 100 problems at a time
skip = 0
has_more = True

while has_more:
        # Prepare variables for the request
        problem_vars = {
                "limit": page_size,
                "skip": skip
        }
        
        # Create the payload
        problem_payload = {
                "query": problem_list_query,
                "variables": problem_vars
        }
        
        # Make the request
        try:
                problem_response = requests.post(url, headers=headers, json=problem_payload)
                problem_data = problem_response.json()
                
                if "data" in problem_data and "problemsetQuestionListV2" in problem_data["data"]:
                        questions = problem_data["data"]["problemsetQuestionListV2"]["questions"]
                        all_problems.extend(questions)
                        
                        # Check if we need to continue pagination
                        if len(questions) < page_size:
                                has_more = False
                        else:
                                skip += page_size
                                
                        print(f"Fetched {len(questions)} problems. Total: {len(all_problems)}")
                else:
                        print("Failed to fetch problems:", problem_data)
                        has_more = False
                        
        except Exception as e:
                print(f"Error fetching problems: {e}")
                has_more = False
                
        # Optional: Add a small delay to avoid rate limiting
        import time
        time.sleep(1)

print(f"Total problems fetched: {len(all_problems)}")
# Out:
# Fetched 100 problems. Total: 100
# Fetched 100 problems. Total: 200
# Fetched 100 problems. Total: 300
# Fetched 100 problems. Total: 400
# Fetched 100 problems. Total: 500
# Fetched 100 problems. Total: 600
# Fetched 100 problems. Total: 700
# Fetched 100 problems. Total: 800
# Fetched 100 problems. Total: 900
# Fetched 100 problems. Total: 1000
# Fetched 100 problems. Total: 1100
# Fetched 100 problems. Total: 1200
# Fetched 100 problems. Total: 1300
# Fetched 100 problems. Total: 1400
# Fetched 100 problems. Total: 1500
# Fetched 100 problems. Total: 1600
# Fetched 100 problems. Total: 1700
# Fetched 100 problems. Total: 1800
# Fetched 100 problems. Total: 1900
# Fetched 100 problems. Total: 2000
# Fetched 100 problems. Total: 2100
# Fetched 100 problems. Total: 2200
# Fetched 100 problems. Total: 2300
# Fetched 100 problems. Total: 2400
# Fetched 100 problems. Total: 2500
# Fetched 100 problems. Total: 2600
# Fetched 100 problems. Total: 2700
# Fetched 100 problems. Total: 2800
# Fetched 100 problems. Total: 2900
# Fetched 100 problems. Total: 3000
# Fetched 100 problems. Total: 3100
# Fetched 100 problems. Total: 3200
# Fetched 100 problems. Total: 3300
# Fetched 100 problems. Total: 3400
# Fetched 100 problems. Total: 3500
# Fetched 100 problems. Total: 3600
# Fetched 86 problems. Total: 3686
# Total problems fetched: 3686

# %%
from bs4 import BeautifulSoup
import re
import psycopg2
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from dotenv import load_dotenv
import os

load_dotenv()  # This loads the .env file

embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

conn = psycopg2.connect(
        dbname="dsa_search",
        user="dsa_user",
        password="dsa_user",
        host="localhost",
        port="5432",
    )

# Create a cursor
cur = conn.cursor()

insert_query = """
INSERT INTO dsa_questions_gemini (title, difficulty, topic, link, description, embedding)
VALUES (%s, %s, %s, %s, %s, %s)
"""
url = "https://leetcode.com/graphql"
headers = {
    "Content-Type": "application/json",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
}

# Query for problem details
query = """
query questionData($titleSlug: String!) {
    question(titleSlug: $titleSlug) {
        questionId
        title
        content
        difficulty
        topicTags {
            name
        }
    }
}
"""
start = 3500
end = 3686
# variables = {"titleSlug": "two-sum"}
for i in range(start, end):
    problem = all_problems[i]
    variables = {"titleSlug": problem["titleSlug"]}
    payload = {"query": query, "variables": variables}
    response = requests.post(url, headers=headers, json=payload)
    data = response.json()   
    if "data" in data and data["data"]["question"]:
        print(f"Fetched problem: {problem['title']}")
        q = data["data"]["question"]
        title = q["title"]
        difficulty = q["difficulty"]
        tags = ", ".join([t["name"] for t in q["topicTags"]])
        # Content is HTML, let's clean it
        raw_html = q["content"]
        if not raw_html:
            print(f"❌ Skipping question '{title}' because content is None")
            continue
        soup = BeautifulSoup(raw_html, "html.parser")
        description_parts = []
        for elem in soup.find_all():
            if elem.get_text().strip().startswith("Example"):
                break
            description_parts.append(str(elem))

        description_html = "\n".join(description_parts)
        description_text = BeautifulSoup(description_html, "html.parser").get_text()
        text = re.sub(r"\s+", " ", description_text).strip()
        embedding = embeddings.embed_query(text)
        cur.execute(insert_query, (title, difficulty, tags, f"https://leetcode.com/problems/{problem['titleSlug']}", text, embedding))

    else:
        print("❌ Failed:", data)

conn.commit()
cur.close()
conn.close()
# Out:
# Fetched problem: Maximize Active Section with Trade II
# Fetched problem: Minimum Cost to Reach Every Position
# Fetched problem: Longest Palindrome After Substring Concatenation I
# Fetched problem: Longest Palindrome After Substring Concatenation II
# Fetched problem: Minimum Operations to Make Elements Within K Subarrays Equal
# Fetched problem: Find Time Required to Eliminate Bacterial Strains
# ❌ Skipping question 'Find Time Required to Eliminate Bacterial Strains' because content is None
# Fetched problem: Minimum Pair Removal to Sort Array I
# Fetched problem: Implement Router
# Fetched problem: Maximum Product of Subsequences With an Alternating Sum Equal to K
# Fetched problem: Minimum Pair Removal to Sort Array II
# Fetched problem: Make a Positive Array
# ❌ Skipping question 'Make a Positive Array' because content is None
# Fetched problem: Minimum Operations to Make Array Sum Divisible by K
# Fetched problem: Number of Unique XOR Triplets I
# Fetched problem: Number of Unique XOR Triplets II
# Fetched problem: Shortest Path in a Weighted Tree
# Fetched problem: Find Closest Person
# Fetched problem: Smallest Palindromic Rearrangement I
# Fetched problem: Smallest Palindromic Rearrangement II
# Fetched problem: Count Numbers with Non-Decreasing Digits
# Fetched problem: Minimum Threshold for Inversion Pairs Count
# ❌ Skipping question 'Minimum Threshold for Inversion Pairs Count' because content is None
# Fetched problem: Find Product Recommendation Pairs
# Fetched problem: Calculate Score After Performing Instructions
# Fetched problem: Make Array Non-decreasing
# Fetched problem: Find X Value of Array I
# Fetched problem: Find X Value of Array II
# Fetched problem: Range XOR Queries with Subarray Reversals
# ❌ Skipping question 'Range XOR Queries with Subarray Reversals' because content is None
# Fetched problem: Find the Most Common Response
# Fetched problem: Unit Conversion I
# Fetched problem: Count Cells in Overlapping Horizontal and Vertical Substrings
# Fetched problem: Maximum Profit from Valid Topological Order in DAG
# Fetched problem: Count Covered Buildings
# Fetched problem: Path Existence Queries in a Graph I
# Fetched problem: Concatenated Divisibility
# Fetched problem: Path Existence Queries in a Graph II
# Fetched problem: Unit Conversion II
# ❌ Skipping question 'Unit Conversion II' because content is None
# Fetched problem: Maximum Product of Two Digits
# Fetched problem: Fill a Special Grid
# Fetched problem: Merge Operations for Minimum Travel Time
# Fetched problem: Find Sum of Array Product of Magical Sequences
# Fetched problem: Minimum Time to Visit All Houses
# ❌ Skipping question 'Minimum Time to Visit All Houses' because content is None
# Fetched problem: Find Most Frequent Vowel and Consonant
# Fetched problem: Minimum Operations to Convert All Elements to Zero
# Fetched problem: Maximum Weighted K-Edge Path
# Fetched problem: Subtree Inversion Sum
# Fetched problem: Minimum Deletions for At Most K Distinct Characters
# Fetched problem: Equal Sum Grid Partition I
# Fetched problem: Maximum Sum of Edge Values in a Graph
# Fetched problem: Equal Sum Grid Partition II
# Fetched problem: Multiply Two Polynomials
# ❌ Skipping question 'Multiply Two Polynomials' because content is None
# Fetched problem: Smallest Index With Digit Sum Equal to Index
# Fetched problem: Minimum Swaps to Sort by Digit Sum
# Fetched problem: Grid Teleportation Traversal
# Fetched problem: Minimum Weighted Subgraph With the Required Paths II
# Fetched problem: Find Category Recommendation Pairs
# Fetched problem: Smallest Subarray to Sort in Every Sliding Window
# ❌ Skipping question 'Smallest Subarray to Sort in Every Sliding Window' because content is None
# Fetched problem: Sum of Largest Prime Substrings
# Fetched problem: Find Maximum Number of Non Intersecting Substrings
# Fetched problem: Number of Ways to Assign Edge Weights I
# Fetched problem: Number of Ways to Assign Edge Weights II
# Fetched problem: Find Minimum Log Transportation Cost
# Fetched problem: Resulting String After Adjacent Removals
# Fetched problem: Maximum Profit from Trading Stocks with Discounts
# Fetched problem: Lexicographically Smallest String After Adjacent Removals
# Fetched problem: Seasonal Sales Analysis
# Fetched problem: Sequential Grid Path Cover
# ❌ Skipping question 'Sequential Grid Path Cover' because content is None
# Fetched problem: Partition Array into Two Equal Product Subsets
# Fetched problem: Minimum Absolute Difference in Sliding Submatrix
# Fetched problem: Minimum Moves to Clean the Classroom
# Fetched problem: Maximize Count of Distinct Primes After Split
# Fetched problem: Find Books with No Available Copies
# Fetched problem: Find the Shortest Superstring II
# ❌ Skipping question 'Find the Shortest Superstring II' because content is None
# Fetched problem: Maximize Y‑Sum by Picking a Triplet of Distinct X‑Values
# Fetched problem: Best Time to Buy and Sell Stock V
# Fetched problem: Maximize Subarray GCD Score
# Fetched problem: Maximum Good Subtree Score
# Fetched problem: Transform Array to All Equal Elements
# Fetched problem: Count the Number of Computer Unlocking Permutations
# Fetched problem: Count Partitions With Max-Min Difference at Most K
# Fetched problem: Minimum Steps to Convert String with Operations
# Fetched problem: Find Consistently Improving Employees
# Fetched problem: Count Odd Letters from Number
# ❌ Skipping question 'Count Odd Letters from Number' because content is None
# Fetched problem: Generate Tag for Video Caption
# Fetched problem: Count Special Triplets
# Fetched problem: Maximum Product of First and Last Elements of a Subsequence
# Fetched problem: Find Weighted Median Node in Tree
# Fetched problem: Find COVID Recovery Patients
# Fetched problem: Minimum Adjacent Swaps to Alternate Parity
# Fetched problem: Find Maximum Area of a Triangle
# Fetched problem: Count Prime-Gap Balanced Subarrays
# Fetched problem: Kth Smallest Path XOR Sum
# Fetched problem: Check if Any Element Has Prime Frequency
# Fetched problem: Inverse Coin Change
# Fetched problem: Minimum Increments to Equalize Leaf Paths
# Fetched problem: Minimum Time to Transport All Individuals
# Fetched problem: Once Twice
# ❌ Skipping question 'Once Twice' because content is None
# Fetched problem: Minimum Cost Path with Alternating Directions I
# ❌ Skipping question 'Minimum Cost Path with Alternating Directions I' because content is None
# Fetched problem: Partition String
# Fetched problem: Longest Common Prefix Between Adjacent Strings After Removals
# Fetched problem: Partition Array to Minimize XOR
# Fetched problem: Maximize Spanning Tree Stability with Upgrades
# Fetched problem: Find Drivers with Improved Fuel Efficiency
# Fetched problem: Hexadecimal and Hexatrigesimal Conversion
# Fetched problem: Minimum Cost Path with Alternating Directions II
# Fetched problem: Minimum Time to Reach Destination in Directed Graph
# Fetched problem: Minimum Stability Factor of Array
# Fetched problem: Coupon Code Validator
# Fetched problem: Power Grid Maintenance
# Fetched problem: Minimum Time for K Connected Components
# Fetched problem: Minimum Moves to Reach Target in Grid
# Fetched problem: Minimum Number of Primes to Sum to Target
# ❌ Skipping question 'Minimum Number of Primes to Sum to Target' because content is None
# Fetched problem: Find Overbooked Employees
# Fetched problem: Process String with Special Operations I
# Fetched problem: Minimize Maximum Component Cost
# Fetched problem: Process String with Special Operations II
# Fetched problem: Longest Palindromic Path in Graph
# Fetched problem: Number of Student Replacements
# ❌ Skipping question 'Number of Student Replacements' because content is None
# Fetched problem: Find Students with Study Spiral Pattern
# Fetched problem: Split Array by Prime Indices
# Fetched problem: Count Islands With Total Value Divisible by K
# Fetched problem: Network Recovery Pathways
# Fetched problem: Number of Integers With Popcount-Depth Equal to K I
# Fetched problem: Check Divisibility by Digit Sum and Product
# Fetched problem: Count Number of Trapezoids I
# Fetched problem: Number of Integers With Popcount-Depth Equal to K II
# Fetched problem: Count Number of Trapezoids II
# Fetched problem: Find Stores with Inventory Imbalance
# Fetched problem: Maximum Median Sum of Subsequences of Size 3
# Fetched problem: Maximum Number of Subsequences After One Inserting
# Fetched problem: Minimum Jumps to Reach End via Prime Teleportation
# Fetched problem: Partition Array for Maximum XOR and AND
# Fetched problem: Sort Threats by Severity and Exploitability
# ❌ Skipping question 'Sort Threats by Severity and Exploitability' because content is None
# Fetched problem: Subarrays with XOR at Least K
# ❌ Skipping question 'Subarrays with XOR at Least K' because content is None
# Fetched problem: Earliest Finish Time for Land and Water Rides I
# Fetched problem: Minimum Removals to Balance Array
# Fetched problem: Earliest Finish Time for Land and Water Rides II
# Fetched problem: Threshold Majority Queries
# Fetched problem: Trionic Array I
# Fetched problem: Maximum Balanced Shipments
# Fetched problem: Minimum Time to Activate String
# Fetched problem: Trionic Array II
# Fetched problem: Longest Semi-Repeating Subarray
# ❌ Skipping question 'Longest Semi-Repeating Subarray' because content is None
# Fetched problem: Find Books with Polarized Opinions
# Fetched problem: Flip Square Submatrix Vertically
# Fetched problem: Maximum K to Sort a Permutation
# Fetched problem: Maximum Total from Optimal Activation Order
# Fetched problem: Next Special Palindrome Number
# Fetched problem: Maximum Weight in Two Bags
# ❌ Skipping question 'Maximum Weight in Two Bags' because content is None
# Fetched problem: Minimum Sensors to Cover Grid
# Fetched problem: Number of Perfect Pairs
# Fetched problem: Minimum Cost Path with Edge Reversals
# Fetched problem: Minimum Cost Path with Teleportations
# Fetched problem: Best Time to Buy and Sell Stock using Strategy
# Fetched problem: XOR After Range Multiplication Queries I
# Fetched problem: Minimum Sum After Divisible Sum Deletions
# Fetched problem: XOR After Range Multiplication Queries II
# Fetched problem: Determine if a Simple Graph Exists
# ❌ Skipping question 'Determine if a Simple Graph Exists' because content is None
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}
# ❌ Failed: {'data': {'question': None}}

# %% [markdown]
# ### Adjacency list creation

# %%
import psycopg2
import numpy as np
import ipywidgets
from sklearn.metrics.pairwise import cosine_similarity
from tqdm.notebook import tqdm
import ast  # for safely parsing string to list

# Connect to PostgreSQL
conn = psycopg2.connect(
    dbname="dsa_search",
    user="dsa_user",
    password="dsa_user",
    host="localhost",
    port="5432",
)
cur = conn.cursor()

# Fetch all questions and embeddings
cur.execute("SELECT id, embedding FROM dsa_questions_gemini")
rows = cur.fetchall()

ids = [row[0] for row in rows]

# Parse embeddings string to list of floats
embeddings = []
for row in rows:
    emb_str = row[1]  # This is coming as string like '[-0.00898, ...]'
    if isinstance(emb_str, str):
        emb_list = ast.literal_eval(emb_str)  # safely convert to list
    else:
        emb_list = row[1]
    embeddings.append(emb_list)

embeddings = np.array(embeddings, dtype=np.float32)

# Cosine similarity threshold
THRESHOLD = 0.8
TOP_K = 10  # number of neighbors to store

# Prepare insert query
insert_query = """
INSERT INTO dsa_question_edges_gemini (source_id, target_id, score)
VALUES (%s, %s, %s)
ON CONFLICT (source_id, target_id) DO NOTHING
"""

# Compute pairwise cosine similarity and store top-K neighbors
for i in tqdm(range(len(ids))):
    src_id = ids[i]
    src_emb = embeddings[i].reshape(1, -1)

    sims = cosine_similarity(src_emb, embeddings)[0]
    sims[i] = -1  # ignore self

    top_k_idx = sims.argsort()[-TOP_K:][::-1]

    for idx in top_k_idx:
        if sims[idx] >= THRESHOLD:
            cur.execute(insert_query, (src_id, ids[idx], float(sims[idx])))

conn.commit()
cur.close()
conn.close()
print("✅ Knowledge graph edges stored successfully!")
# Out:
#   0%|          | 0/3327 [00:00<?, ?it/s]
# ✅ Knowledge graph edges stored successfully!

# %% [markdown]
# ### Tfidf embeddings

# %%
import psycopg2
import json
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
import string

# Download NLTK data if not already
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("omw-1.4")

# --------------------------
# Preprocessing function
# --------------------------
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()


def preprocess_text(text):
    text = text.lower()
    text = text.replace("\n", " ").replace("\r", " ").replace("\t", " ")
    text = text.translate(str.maketrans("", "", string.punctuation))
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(tok) for tok in tokens if tok not in stop_words]
    return " ".join(tokens)


# --------------------------
# Database connection
# --------------------------
conn = psycopg2.connect(
    dbname="dsa_search",
    user="dsa_user",
    password="dsa_user",
    host="localhost",
    port="5432",
)
cur = conn.cursor()

# --------------------------
# Retrieve existing data
# --------------------------
cur.execute(
    "SELECT id, title, description, difficulty, topic, link FROM dsa_questions_gemini;"
)
rows = cur.fetchall()

# --------------------------
# Preprocess documents
# --------------------------
documents = [
    preprocess_text(f"{row[1]} {row[2]}") for row in rows
]  # title + description

# --------------------------
# Build TF-IDF embeddings
# --------------------------
vectorizer = TfidfVectorizer(max_features=3000)  # limit features to reduce size
X = vectorizer.fit_transform(documents)

conn.commit()

# --------------------------
# Insert embeddings into DB
# --------------------------
for i, row in enumerate(rows):
    tfidf_vector = X[i].toarray()[0]
    tfidf_dict = {
        str(j): float(tfidf_vector[j]) for j in tfidf_vector.nonzero()[0]
    }  # sparse dict

    cur.execute(
        """
        INSERT INTO dsa_questions_tfidf (title, description, difficulty, topic, link, embedding)
        VALUES (%s, %s, %s, %s, %s, %s)
        """,
        (row[1], row[2], row[3], row[4], row[5], json.dumps(tfidf_dict)),
    )

conn.commit()
cur.close()
conn.close()

print("TF-IDF embeddings generated and stored successfully!")
# Out:
# [nltk_data] Downloading package stopwords to /home/prasad/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/prasad/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/prasad/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# TF-IDF embeddings generated and stored successfully!

# %%
import joblib
joblib.dump(vectorizer, "tfidf_vectorizer.pkl")
print("✅ TF-IDF Vectorizer saved to tfidf_vectorizer.pkl")
# Out:
# ✅ TF-IDF Vectorizer saved to tfidf_vectorizer.pkl

# %%
import psycopg2
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import json

# --------------------------
# DB connection
# --------------------------
conn = psycopg2.connect(
    dbname="dsa_search",
    user="dsa_user",
    password="dsa_user",
    host="localhost",
    port="5432",
)
cur = conn.cursor()

# --------------------------
# Fetch all questions and TF-IDF embeddings
# --------------------------
cur.execute("SELECT id, embedding FROM dsa_questions_tfidf")
rows = cur.fetchall()

ids = [row[0] for row in rows]

# Parse embeddings JSON to numpy array
embeddings = []
for row in rows:
    emb_data = row[1]
    if isinstance(emb_data, str):
        emb_dict = json.loads(emb_data)
    elif isinstance(emb_data, dict):
        emb_dict = emb_data
    else:
        raise TypeError(f"Unexpected embedding type: {type(emb_data)}")
    # Convert sparse dict to dense array
    max_idx = max([int(k) for k in emb_dict.keys()]) + 1 if emb_dict else 0
    emb = np.zeros(max_idx, dtype=np.float32)
    for k, v in emb_dict.items():
        emb[int(k)] = v
    embeddings.append(emb)

# Pad all vectors to same length (TF-IDF vectors may vary in length)
max_len = max([len(e) for e in embeddings])
embeddings = np.array(
    [np.pad(e, (0, max_len - len(e))) for e in embeddings], dtype=np.float32
)

# --------------------------
# Cosine similarity parameters
# --------------------------
THRESHOLD = 0.3  # TF-IDF vectors are sparse; similarity will be lower
TOP_K = 10  # number of neighbors

# --------------------------
# Create adjacency list in DB
# --------------------------

conn.commit()

insert_query = """
INSERT INTO dsa_question_edges_tfidf (source_id, target_id, score)
VALUES (%s, %s, %s)
ON CONFLICT (source_id, target_id) DO NOTHING
"""

# --------------------------
# Compute top-K cosine similarity
# --------------------------
for i in tqdm(range(len(ids))):
    src_id = ids[i]
    src_emb = embeddings[i].reshape(1, -1)

    sims = cosine_similarity(src_emb, embeddings)[0]
    sims[i] = -1  # ignore self

    top_k_idx = sims.argsort()[-TOP_K:][::-1]

    for idx in top_k_idx:
        if sims[idx] >= THRESHOLD:
            cur.execute(insert_query, (src_id, ids[idx], float(sims[idx])))

conn.commit()
cur.close()
conn.close()
print("✅ TF-IDF knowledge graph edges stored successfully!")
# Out:
# 100%|██████████| 2927/2927 [01:28<00:00, 33.23it/s]
# ✅ TF-IDF knowledge graph edges stored successfully!

# %% [markdown]
# ### CSES problme seet

# %%
import requests
from bs4 import BeautifulSoup
import psycopg2
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import dotenv


dotenv.load_dotenv()  # This loads the .env file

embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

conn = psycopg2.connect(
    dbname="dsa_search",
    user="dsa_user",
    password="dsa_user",
    host="localhost",
    port="5432",
)

# Create a cursor
cur = conn.cursor()

insert_query = """
INSERT INTO dsa_questions_gemini (title, difficulty, topic, link, description, embedding)
VALUES (%s, %s, %s, %s, %s, %s)
"""

problemset = "https://cses.fi/problemset/list/"

res = requests.get(problemset)
soup = BeautifulSoup(res.text, "html.parser")
problems = soup.find_all("a", href=True)
for i in range(8, len(problems)):
    print(problems[i].text, problems[i].get("href"))  # type: ignore
    url = f"https://cses.fi{problems[i].get('href')}"  # type: ignore
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")
    title = soup.find("title").text # type: ignore
    description = soup.find("p").text # type: ignore
    link = url
    difficulty = "Unknown"
    topic = "Unknown"
    embedding = embeddings.embed_query(description)
    cur.execute(insert_query, (title, difficulty, topic, link, description, embedding))
    print(title)

conn.commit()
cur.close()
conn.close()
# Out:
# Weird Algorithm /problemset/task/1068
# CSES - Weird Algorithm
# Missing Number /problemset/task/1083
# CSES - Missing Number
# Repetitions /problemset/task/1069
# CSES - Repetitions
# Increasing Array /problemset/task/1094
# CSES - Increasing Array
# Permutations /problemset/task/1070
# CSES - Permutations
# Number Spiral /problemset/task/1071
# CSES - Number Spiral
# Two Knights /problemset/task/1072
# CSES - Two Knights
# Two Sets /problemset/task/1092
# CSES - Two Sets
# Bit Strings /problemset/task/1617
# CSES - Bit Strings
# Trailing Zeros /problemset/task/1618
# CSES - Trailing Zeros
# Coin Piles /problemset/task/1754
# CSES - Coin Piles
# Palindrome Reorder /problemset/task/1755
# CSES - Palindrome Reorder
# Gray Code /problemset/task/2205
# CSES - Gray Code
# Tower of Hanoi /problemset/task/2165
# CSES - Tower of Hanoi
# Creating Strings /problemset/task/1622
# CSES - Creating Strings
# Apple Division /problemset/task/1623
# CSES - Apple Division
# Chessboard and Queens /problemset/task/1624
# CSES - Chessboard and Queens
# Raab Game I /problemset/task/3399
# CSES - Raab Game I
# Mex Grid Construction /problemset/task/3419
# CSES - Mex Grid Construction
# Knight Moves Grid /problemset/task/3217
# CSES - Knight Moves Grid
# Grid Coloring I /problemset/task/3311
# CSES - Grid Coloring I
# Digit Queries /problemset/task/2431
# CSES - Digit Queries
# String Reorder /problemset/task/1743
# CSES - String Reorder
# Grid Path Description /problemset/task/1625
# CSES - Grid Path Description
# Distinct Numbers /problemset/task/1621
# CSES - Distinct Numbers
# Apartments /problemset/task/1084
# CSES - Apartments
# Ferris Wheel /problemset/task/1090
# CSES - Ferris Wheel
# Concert Tickets /problemset/task/1091
# CSES - Concert Tickets
# Restaurant Customers /problemset/task/1619
# CSES - Restaurant Customers
# Movie Festival /problemset/task/1629
# CSES - Movie Festival
# Sum of Two Values /problemset/task/1640
# CSES - Sum of Two Values
# Maximum Subarray Sum /problemset/task/1643
# CSES - Maximum Subarray Sum
# Stick Lengths /problemset/task/1074
# CSES - Stick Lengths
# Missing Coin Sum /problemset/task/2183
# CSES - Missing Coin Sum
# Collecting Numbers /problemset/task/2216
# CSES - Collecting Numbers
# Collecting Numbers II /problemset/task/2217
# CSES - Collecting Numbers II
# Playlist /problemset/task/1141
# CSES - Playlist
# Towers /problemset/task/1073
# CSES - Towers
# Traffic Lights /problemset/task/1163
# CSES - Traffic Lights
# Distinct Values Subarrays /problemset/task/3420
# CSES - Distinct Values Subarrays
# Distinct Values Subsequences /problemset/task/3421
# CSES - Distinct Values Subsequences
# Josephus Problem I /problemset/task/2162
# CSES - Josephus Problem I
# Josephus Problem II /problemset/task/2163
# CSES - Josephus Problem II
# Nested Ranges Check /problemset/task/2168
# CSES - Nested Ranges Check
# Nested Ranges Count /problemset/task/2169
# CSES - Nested Ranges Count
# Room Allocation /problemset/task/1164
# CSES - Room Allocation
# Factory Machines /problemset/task/1620
# CSES - Factory Machines
# Tasks and Deadlines /problemset/task/1630
# CSES - Tasks and Deadlines
# Reading Books /problemset/task/1631
# CSES - Reading Books
# Sum of Three Values /problemset/task/1641
# CSES - Sum of Three Values
# Sum of Four Values /problemset/task/1642
# CSES - Sum of Four Values
# Nearest Smaller Values /problemset/task/1645
# CSES - Nearest Smaller Values
# Subarray Sums I /problemset/task/1660
# CSES - Subarray Sums I
# Subarray Sums II /problemset/task/1661
# CSES - Subarray Sums II
# Subarray Divisibility /problemset/task/1662
# CSES - Subarray Divisibility
# Distinct Values Subarrays II /problemset/task/2428
# CSES - Distinct Values Subarrays II
# Array Division /problemset/task/1085
# CSES - Array Division
# Movie Festival II /problemset/task/1632
# CSES - Movie Festival II
# Maximum Subarray Sum II /problemset/task/1644
# CSES - Maximum Subarray Sum II
# Dice Combinations /problemset/task/1633
# CSES - Dice Combinations
# Minimizing Coins /problemset/task/1634
# CSES - Minimizing Coins
# Coin Combinations I /problemset/task/1635
# CSES - Coin Combinations I
# Coin Combinations II /problemset/task/1636
# CSES - Coin Combinations II
# Removing Digits /problemset/task/1637
# CSES - Removing Digits
# Grid Paths I /problemset/task/1638
# CSES - Grid Paths I
# Book Shop /problemset/task/1158
# CSES - Book Shop
# Array Description /problemset/task/1746
# CSES - Array Description
# Counting Towers /problemset/task/2413
# CSES - Counting Towers
# Edit Distance /problemset/task/1639
# CSES - Edit Distance
# Longest Common Subsequence /problemset/task/3403
# CSES - Longest Common Subsequence
# Rectangle Cutting /problemset/task/1744
# CSES - Rectangle Cutting
# Minimal Grid Path /problemset/task/3359
# CSES - Minimal Grid Path
# Money Sums /problemset/task/1745
# CSES - Money Sums
# Removal Game /problemset/task/1097
# CSES - Removal Game
# Two Sets II /problemset/task/1093
# CSES - Two Sets II
# Mountain Range /problemset/task/3314
# CSES - Mountain Range
# Increasing Subsequence /problemset/task/1145
# CSES - Increasing Subsequence
# Projects /problemset/task/1140
# CSES - Projects
# Elevator Rides /problemset/task/1653
# CSES - Elevator Rides
# Counting Tilings /problemset/task/2181
# CSES - Counting Tilings
# Counting Numbers /problemset/task/2220
# CSES - Counting Numbers
# Increasing Subsequence II /problemset/task/1748
# CSES - Increasing Subsequence II
# Counting Rooms /problemset/task/1192
# CSES - Counting Rooms
# Labyrinth /problemset/task/1193
# CSES - Labyrinth
# Building Roads /problemset/task/1666
# CSES - Building Roads
# Message Route /problemset/task/1667
# CSES - Message Route
# Building Teams /problemset/task/1668
# CSES - Building Teams
# Round Trip /problemset/task/1669
# CSES - Round Trip
# Monsters /problemset/task/1194
# CSES - Monsters
# Shortest Routes I /problemset/task/1671
# CSES - Shortest Routes I
# Shortest Routes II /problemset/task/1672
# CSES - Shortest Routes II
# High Score /problemset/task/1673
# CSES - High Score
# Flight Discount /problemset/task/1195
# CSES - Flight Discount
# Cycle Finding /problemset/task/1197
# CSES - Cycle Finding
# Flight Routes /problemset/task/1196
# CSES - Flight Routes
# Round Trip II /problemset/task/1678
# CSES - Round Trip II
# Course Schedule /problemset/task/1679
# CSES - Course Schedule
# Longest Flight Route /problemset/task/1680
# CSES - Longest Flight Route
# Game Routes /problemset/task/1681
# CSES - Game Routes
# Investigation /problemset/task/1202
# CSES - Investigation
# Planets Queries I /problemset/task/1750
# CSES - Planets Queries I
# Planets Queries II /problemset/task/1160
# CSES - Planets Queries II
# Planets Cycles /problemset/task/1751
# CSES - Planets Cycles
# Road Reparation /problemset/task/1675
# CSES - Road Reparation
# Road Construction /problemset/task/1676
# CSES - Road Construction
# Flight Routes Check /problemset/task/1682
# CSES - Flight Routes Check
# Planets and Kingdoms /problemset/task/1683
# CSES - Planets and Kingdoms
# Giant Pizza /problemset/task/1684
# CSES - Giant Pizza
# Coin Collector /problemset/task/1686
# CSES - Coin Collector
# Mail Delivery /problemset/task/1691
# CSES - Mail Delivery
# De Bruijn Sequence /problemset/task/1692
# CSES - De Bruijn Sequence
# Teleporters Path /problemset/task/1693
# CSES - Teleporters Path
# Hamiltonian Flights /problemset/task/1690
# CSES - Hamiltonian Flights
# Knight's Tour /problemset/task/1689
# CSES - Knight's Tour
# Download Speed /problemset/task/1694
# CSES - Download Speed
# Police Chase /problemset/task/1695
# CSES - Police Chase
# School Dance /problemset/task/1696
# CSES - School Dance
# Distinct Routes /problemset/task/1711
# CSES - Distinct Routes
# Static Range Sum Queries /problemset/task/1646
# CSES - Static Range Sum Queries
# Static Range Minimum Queries /problemset/task/1647
# CSES - Static Range Minimum Queries
# Dynamic Range Sum Queries /problemset/task/1648
# CSES - Dynamic Range Sum Queries
# Dynamic Range Minimum Queries /problemset/task/1649
# CSES - Dynamic Range Minimum Queries
# Range Xor Queries /problemset/task/1650
# CSES - Range Xor Queries
# Range Update Queries /problemset/task/1651
# CSES - Range Update Queries
# Forest Queries /problemset/task/1652
# CSES - Forest Queries
# Hotel Queries /problemset/task/1143
# CSES - Hotel Queries
# List Removals /problemset/task/1749
# CSES - List Removals
# Salary Queries /problemset/task/1144
# CSES - Salary Queries
# Prefix Sum Queries /problemset/task/2166
# CSES - Prefix Sum Queries
# Pizzeria Queries /problemset/task/2206
# CSES - Pizzeria Queries
# Visible Buildings Queries /problemset/task/3304
# CSES - Visible Buildings Queries
# Range Interval Queries /problemset/task/3163
# CSES - Range Interval Queries
# Subarray Sum Queries /problemset/task/1190
# CSES - Subarray Sum Queries
# Subarray Sum Queries II /problemset/task/3226
# CSES - Subarray Sum Queries II
# Distinct Values Queries /problemset/task/1734
# CSES - Distinct Values Queries
# Distinct Values Queries II /problemset/task/3356
# CSES - Distinct Values Queries II
# Increasing Array Queries /problemset/task/2416
# CSES - Increasing Array Queries
# Movie Festival Queries /problemset/task/1664
# CSES - Movie Festival Queries
# Forest Queries II /problemset/task/1739
# CSES - Forest Queries II
# Range Updates and Sums /problemset/task/1735
# CSES - Range Updates and Sums
# Polynomial Queries /problemset/task/1736
# CSES - Polynomial Queries
# Range Queries and Copies /problemset/task/1737
# CSES - Range Queries and Copies
# Missing Coin Sum Queries /problemset/task/2184
# CSES - Missing Coin Sum Queries
# Subordinates /problemset/task/1674
# CSES - Subordinates
# Tree Matching /problemset/task/1130
# CSES - Tree Matching
# Tree Diameter /problemset/task/1131
# CSES - Tree Diameter
# Tree Distances I /problemset/task/1132
# CSES - Tree Distances I
# Tree Distances II /problemset/task/1133
# CSES - Tree Distances II
# Company Queries I /problemset/task/1687
# CSES - Company Queries I
# Company Queries II /problemset/task/1688
# CSES - Company Queries II
# Distance Queries /problemset/task/1135
# CSES - Distance Queries
# Counting Paths /problemset/task/1136
# CSES - Counting Paths
# Subtree Queries /problemset/task/1137
# CSES - Subtree Queries
# Path Queries /problemset/task/1138
# CSES - Path Queries
# Path Queries II /problemset/task/2134
# CSES - Path Queries II
# Distinct Colors /problemset/task/1139
# CSES - Distinct Colors
# Finding a Centroid /problemset/task/2079
# CSES - Finding a Centroid
# Fixed-Length Paths I /problemset/task/2080
# CSES - Fixed-Length Paths I
# Fixed-Length Paths II /problemset/task/2081
# CSES - Fixed-Length Paths II
# Josephus Queries /problemset/task/2164
# CSES - Josephus Queries
# Exponentiation /problemset/task/1095
# CSES - Exponentiation
# Exponentiation II /problemset/task/1712
# CSES - Exponentiation II
# Counting Divisors /problemset/task/1713
# CSES - Counting Divisors
# Common Divisors /problemset/task/1081
# CSES - Common Divisors
# Sum of Divisors /problemset/task/1082
# CSES - Sum of Divisors
# Divisor Analysis /problemset/task/2182
# CSES - Divisor Analysis
# Prime Multiples /problemset/task/2185
# CSES - Prime Multiples
# Counting Coprime Pairs /problemset/task/2417
# CSES - Counting Coprime Pairs
# Next Prime /problemset/task/3396
# CSES - Next Prime
# Binomial Coefficients /problemset/task/1079
# CSES - Binomial Coefficients
# Creating Strings II /problemset/task/1715
# CSES - Creating Strings II
# Distributing Apples /problemset/task/1716
# CSES - Distributing Apples
# Christmas Party /problemset/task/1717
# CSES - Christmas Party
# Permutation Order /problemset/task/3397
# CSES - Permutation Order
# Permutation Rounds /problemset/task/3398
# CSES - Permutation Rounds
# Bracket Sequences I /problemset/task/2064
# CSES - Bracket Sequences I
# Bracket Sequences II /problemset/task/2187
# CSES - Bracket Sequences II
# Counting Necklaces /problemset/task/2209
# CSES - Counting Necklaces
# Counting Grids /problemset/task/2210
# CSES - Counting Grids
# Fibonacci Numbers /problemset/task/1722
# CSES - Fibonacci Numbers
# Throwing Dice /problemset/task/1096
# CSES - Throwing Dice
# Graph Paths I /problemset/task/1723
# CSES - Graph Paths I
# Graph Paths II /problemset/task/1724
# CSES - Graph Paths II
# System of Linear Equations /problemset/task/3154
# CSES - System of Linear Equations
# Sum of Four Squares /problemset/task/3355
# CSES - Sum of Four Squares
# Triangle Number Sums /problemset/task/3406
# CSES - Triangle Number Sums
# Dice Probability /problemset/task/1725
# CSES - Dice Probability
# Moving Robots /problemset/task/1726
# CSES - Moving Robots
# Candy Lottery /problemset/task/1727
# CSES - Candy Lottery
# Inversion Probability /problemset/task/1728
# CSES - Inversion Probability
# Stick Game /problemset/task/1729
# CSES - Stick Game
# Nim Game I /problemset/task/1730
# CSES - Nim Game I
# Nim Game II /problemset/task/1098
# CSES - Nim Game II
# Stair Game /problemset/task/1099
# CSES - Stair Game
# Grundy's Game /problemset/task/2207
# CSES - Grundy's Game
# Another Game /problemset/task/2208
# CSES - Another Game
# Word Combinations /problemset/task/1731
# CSES - Word Combinations
# String Matching /problemset/task/1753
# CSES - String Matching
# Finding Borders /problemset/task/1732
# CSES - Finding Borders
# Finding Periods /problemset/task/1733
# CSES - Finding Periods
# Minimal Rotation /problemset/task/1110
# CSES - Minimal Rotation
# Longest Palindrome /problemset/task/1111
# CSES - Longest Palindrome
# All Palindromes /problemset/task/3138
# CSES - All Palindromes
# Required Substring /problemset/task/1112
# CSES - Required Substring
# Palindrome Queries /problemset/task/2420
# CSES - Palindrome Queries
# Finding Patterns /problemset/task/2102
# CSES - Finding Patterns
# Counting Patterns /problemset/task/2103
# CSES - Counting Patterns
# Pattern Positions /problemset/task/2104
# CSES - Pattern Positions
# Distinct Substrings /problemset/task/2105
# CSES - Distinct Substrings
# Distinct Subsequences /problemset/task/1149
# CSES - Distinct Subsequences
# Repeating Substring /problemset/task/2106
# CSES - Repeating Substring
# String Functions /problemset/task/2107
# CSES - String Functions
# Inverse Suffix Array /problemset/task/3225
# CSES - Inverse Suffix Array
# String Transform /problemset/task/1113
# CSES - String Transform
# Substring Order I /problemset/task/2108
# CSES - Substring Order I
# Substring Order II /problemset/task/2109
# CSES - Substring Order II
# Substring Distribution /problemset/task/2110
# CSES - Substring Distribution
# Point Location Test /problemset/task/2189
# CSES - Point Location Test
# Line Segment Intersection /problemset/task/2190
# CSES - Line Segment Intersection
# Polygon Area /problemset/task/2191
# CSES - Polygon Area
# Point in Polygon /problemset/task/2192
# CSES - Point in Polygon
# Polygon Lattice Points /problemset/task/2193
# CSES - Polygon Lattice Points
# Minimum Euclidean Distance /problemset/task/2194
# CSES - Minimum Euclidean Distance
# Convex Hull /problemset/task/2195
# CSES - Convex Hull
# Maximum Manhattan Distances /problemset/task/3410
# CSES - Maximum Manhattan Distances
# All Manhattan Distances /problemset/task/3411
# CSES - All Manhattan Distances
# Intersection Points /problemset/task/1740
# CSES - Intersection Points
# Line Segments Trace I /problemset/task/3427
# CSES - Line Segments Trace I
# Line Segments Trace II /problemset/task/3428
# CSES - Line Segments Trace II
# Lines and Queries I /problemset/task/3429
# CSES - Lines and Queries I
# Lines and Queries II /problemset/task/3430
# CSES - Lines and Queries II
# Area of Rectangles /problemset/task/1741
# CSES - Area of Rectangles
# Robot Path /problemset/task/1742
# CSES - Robot Path
# Meet in the Middle /problemset/task/1628
# CSES - Meet in the Middle
# Hamming Distance /problemset/task/2136
# CSES - Hamming Distance
# Corner Subgrid Check /problemset/task/3360
# CSES - Corner Subgrid Check
# Corner Subgrid Count /problemset/task/2137
# CSES - Corner Subgrid Count
# Reachable Nodes /problemset/task/2138
# CSES - Reachable Nodes
# Reachability Queries /problemset/task/2143
# CSES - Reachability Queries
# Cut and Paste /problemset/task/2072
# CSES - Cut and Paste
# Substring Reversals /problemset/task/2073
# CSES - Substring Reversals
# Reversals and Sums /problemset/task/2074
# CSES - Reversals and Sums
# Necessary Roads /problemset/task/2076
# CSES - Necessary Roads
# Necessary Cities /problemset/task/2077
# CSES - Necessary Cities
# Eulerian Subgraphs /problemset/task/2078
# CSES - Eulerian Subgraphs
# Monster Game I /problemset/task/2084
# CSES - Monster Game I
# Monster Game II /problemset/task/2085
# CSES - Monster Game II
# Subarray Squares /problemset/task/2086
# CSES - Subarray Squares
# Houses and Schools /problemset/task/2087
# CSES - Houses and Schools
# Knuth Division /problemset/task/2088
# CSES - Knuth Division
# Apples and Bananas /problemset/task/2111
# CSES - Apples and Bananas
# One Bit Positions /problemset/task/2112
# CSES - One Bit Positions
# Signal Processing /problemset/task/2113
# CSES - Signal Processing
# New Roads Queries /problemset/task/2101
# CSES - New Roads Queries
# Dynamic Connectivity /problemset/task/2133
# CSES - Dynamic Connectivity
# Parcel Delivery /problemset/task/2121
# CSES - Parcel Delivery
# Task Assignment /problemset/task/2129
# CSES - Task Assignment
# Distinct Routes II /problemset/task/2130
# CSES - Distinct Routes II
# Sliding Window Sum /problemset/task/3220
# CSES - Sliding Window Sum
# Sliding Window Minimum /problemset/task/3221
# CSES - Sliding Window Minimum
# Sliding Window Xor /problemset/task/3426
# CSES - Sliding Window Xor
# Sliding Window Or /problemset/task/3405
# CSES - Sliding Window Or
# Sliding Window Distinct Values /problemset/task/3222
# CSES - Sliding Window Distinct Values
# Sliding Window Mode /problemset/task/3224
# CSES - Sliding Window Mode
# Sliding Window Mex /problemset/task/3219
# CSES - Sliding Window Mex
# Sliding Window Median /problemset/task/1076
# CSES - Sliding Window Median
# Sliding Window Cost /problemset/task/1077
# CSES - Sliding Window Cost
# Sliding Window Inversions /problemset/task/3223
# CSES - Sliding Window Inversions
# Sliding Window Advertisement /problemset/task/3227
# CSES - Sliding Window Advertisement
# Hidden Integer /problemset/task/3112
# CSES - Hidden Integer
# Hidden Permutation /problemset/task/3139
# CSES - Hidden Permutation
# K-th Highest Score /problemset/task/3305
# CSES - K-th Highest Score
# Permuted Binary Strings /problemset/task/3228
# CSES - Permuted Binary Strings
# Colored Chairs /problemset/task/3273
# CSES - Colored Chairs
# Inversion Sorting /problemset/task/3140
# CSES - Inversion Sorting
# Counting Bits /problemset/task/1146
# CSES - Counting Bits
# Maximum Xor Subarray /problemset/task/1655
# CSES - Maximum Xor Subarray
# Maximum Xor Subset /problemset/task/3191
# CSES - Maximum Xor Subset
# Number of Subset Xors /problemset/task/3211
# CSES - Number of Subset Xors
# K Subset Xors /problemset/task/3192
# CSES - K Subset Xors
# All Subarray Xors /problemset/task/3233
# CSES - All Subarray Xors
# Xor Pyramid Peak /problemset/task/2419
# CSES - Xor Pyramid Peak
# Xor Pyramid Diagonal /problemset/task/3194
# CSES - Xor Pyramid Diagonal
# Xor Pyramid Row /problemset/task/3195
# CSES - Xor Pyramid Row
# SOS Bit Problem /problemset/task/1654
# CSES - SOS Bit Problem
# And Subset Count /problemset/task/3141
# CSES - And Subset Count
# Inverse Inversions /problemset/task/2214
# CSES - Inverse Inversions
# Monotone Subsequences /problemset/task/2215
# CSES - Monotone Subsequences
# Third Permutation /problemset/task/3422
# CSES - Third Permutation
# Permutation Prime Sums /problemset/task/3423
# CSES - Permutation Prime Sums
# Chess Tournament /problemset/task/1697
# CSES - Chess Tournament
# Distinct Sums Grid /problemset/task/3424
# CSES - Distinct Sums Grid
# Filling Trominos /problemset/task/2423
# CSES - Filling Trominos
# Grid Path Construction /problemset/task/2418
# CSES - Grid Path Construction
# Nearest Shops /problemset/task/3303
# CSES - Nearest Shops
# Prüfer Code /problemset/task/1134
# CSES - Prüfer Code
# Tree Traversals /problemset/task/1702
# CSES - Tree Traversals
# Course Schedule II /problemset/task/1757
# CSES - Course Schedule II
# Acyclic Graph Edges /problemset/task/1756
# CSES - Acyclic Graph Edges
# Strongly Connected Edges /problemset/task/2177
# CSES - Strongly Connected Edges
# Even Outdegree Edges /problemset/task/2179
# CSES - Even Outdegree Edges
# Graph Girth /problemset/task/1707
# CSES - Graph Girth
# Fixed Length Walk Queries /problemset/task/3357
# CSES - Fixed Length Walk Queries
# Transfer Speeds Sum /problemset/task/3111
# CSES - Transfer Speeds Sum
# MST Edge Check /problemset/task/3407
# CSES - MST Edge Check
# MST Edge Set Check /problemset/task/3408
# CSES - MST Edge Set Check
# MST Edge Cost /problemset/task/3409
# CSES - MST Edge Cost
# Network Breakdown /problemset/task/1677
# CSES - Network Breakdown
# Tree Coin Collecting I /problemset/task/3114
# CSES - Tree Coin Collecting I
# Tree Coin Collecting II /problemset/task/3149
# CSES - Tree Coin Collecting II
# Tree Isomorphism I /problemset/task/1700
# CSES - Tree Isomorphism I
# Tree Isomorphism II /problemset/task/1701
# CSES - Tree Isomorphism II
# Flight Route Requests /problemset/task/1699
# CSES - Flight Route Requests
# Critical Cities /problemset/task/1703
# CSES - Critical Cities
# Visiting Cities /problemset/task/1203
# CSES - Visiting Cities
# Graph Coloring /problemset/task/3308
# CSES - Graph Coloring
# Bus Companies /problemset/task/3158
# CSES - Bus Companies
# Split into Two Paths /problemset/task/3358
# CSES - Split into Two Paths
# Network Renovation /problemset/task/1704
# CSES - Network Renovation
# Forbidden Cities /problemset/task/1705
# CSES - Forbidden Cities
# Creating Offices /problemset/task/1752
# CSES - Creating Offices
# New Flight Routes /problemset/task/1685
# CSES - New Flight Routes
# Filled Subgrid Count I /problemset/task/3413
# CSES - Filled Subgrid Count I
# Filled Subgrid Count II /problemset/task/3414
# CSES - Filled Subgrid Count II
# All Letter Subgrid Count I /problemset/task/3415
# CSES - All Letter Subgrid Count I
# All Letter Subgrid Count II /problemset/task/3416
# CSES - All Letter Subgrid Count II
# Border Subgrid Count I /problemset/task/3417
# CSES - Border Subgrid Count I
# Border Subgrid Count II /problemset/task/3418
# CSES - Border Subgrid Count II
# Raab Game II /problemset/task/3400
# CSES - Raab Game II
# Empty String /problemset/task/1080
# CSES - Empty String
# Permutation Inversions /problemset/task/2229
# CSES - Permutation Inversions
# Counting Bishops /problemset/task/2176
# CSES - Counting Bishops
# Counting Sequences /problemset/task/2228
# CSES - Counting Sequences
# Grid Paths II /problemset/task/1078
# CSES - Grid Paths II
# Counting Permutations /problemset/task/1075
# CSES - Counting Permutations
# Grid Completion /problemset/task/2429
# CSES - Grid Completion
# Counting Reorders /problemset/task/2421
# CSES - Counting Reorders
# Tournament Graph Distribution /problemset/task/3232
# CSES - Tournament Graph Distribution
# Collecting Numbers Distribution /problemset/task/3157
# CSES - Collecting Numbers Distribution
# Functional Graph Distribution /problemset/task/2415
# CSES - Functional Graph Distribution
# Shortest Subsequence /problemset/task/1087
# CSES - Shortest Subsequence
# Distinct Values Sum /problemset/task/3150
# CSES - Distinct Values Sum
# Distinct Values Splits /problemset/task/3190
# CSES - Distinct Values Splits
# Swap Game /problemset/task/1670
# CSES - Swap Game
# Beautiful Permutation II /problemset/task/3175
# CSES - Beautiful Permutation II
# Multiplication Table /problemset/task/2422
# CSES - Multiplication Table
# Bubble Sort Rounds I /problemset/task/3151
# CSES - Bubble Sort Rounds I
# Bubble Sort Rounds II /problemset/task/3152
# CSES - Bubble Sort Rounds II
# Nearest Campsites I /problemset/task/3306
# CSES - Nearest Campsites I
# Nearest Campsites II /problemset/task/3307
# CSES - Nearest Campsites II
# Advertisement /problemset/task/1142
# CSES - Advertisement
# Special Substrings /problemset/task/2186
# CSES - Special Substrings
# Counting LCM Arrays /problemset/task/3169
# CSES - Counting LCM Arrays
# Square Subsets /problemset/task/3193
# CSES - Square Subsets
# Subarray Sum Constraints /problemset/task/3294
# CSES - Subarray Sum Constraints
# Water Containers Moves /problemset/task/3213
# CSES - Water Containers Moves
# Water Containers Queries /problemset/task/3214
# CSES - Water Containers Queries
# Stack Weights /problemset/task/2425
# CSES - Stack Weights
# Maximum Average Subarrays /problemset/task/3301
# CSES - Maximum Average Subarrays
# Subsets with Fixed Average /problemset/task/3302
# CSES - Subsets with Fixed Average
# Two Array Average /problemset/task/3361
# CSES - Two Array Average
# Pyramid Array /problemset/task/1747
# CSES - Pyramid Array
# Permutation Subsequence /problemset/task/3404
# CSES - Permutation Subsequence
# Bit Inversions /problemset/task/1188
# CSES - Bit Inversions
# Writing Numbers /problemset/task/1086
# CSES - Writing Numbers
# Letter Pair Move Game /problemset/task/2427
# CSES - Letter Pair Move Game
# Maximum Building I /problemset/task/1147
# CSES - Maximum Building I
# Sorting Methods /problemset/task/1162
# CSES - Sorting Methods
# Cyclic Array /problemset/task/1191
# CSES - Cyclic Array
# List of Sums /problemset/task/2414
# CSES - List of Sums
# Bouncing Ball Steps /problemset/task/3215
# CSES - Bouncing Ball Steps
# Bouncing Ball Cycle /problemset/task/3216
# CSES - Bouncing Ball Cycle
# Knight Moves Queries /problemset/task/3218
# CSES - Knight Moves Queries
# K Subset Sums I /problemset/task/3108
# CSES - K Subset Sums I
# K Subset Sums II /problemset/task/3109
# CSES - K Subset Sums II
# Increasing Array II /problemset/task/2132
# CSES - Increasing Array II
# Food Division /problemset/task/1189
# CSES - Food Division
# Swap Round Sorting /problemset/task/1698
# CSES - Swap Round Sorting
# Binary Subsequences /problemset/task/2430
# CSES - Binary Subsequences
# School Excursion /problemset/task/1706
# CSES - School Excursion
# Coin Grid /problemset/task/1709
# CSES - Coin Grid
# Grid Coloring II /problemset/task/3312
# CSES - Grid Coloring II
# Programmers and Artists /problemset/task/2426
# CSES - Programmers and Artists
# Removing Digits II /problemset/task/2174
# CSES - Removing Digits II
# Coin Arrangement /problemset/task/2180
# CSES - Coin Arrangement
# Replace with Difference /problemset/task/3159
# CSES - Replace with Difference
# Grid Puzzle I /problemset/task/2432
# CSES - Grid Puzzle I
# Grid Puzzle II /problemset/task/2131
# CSES - Grid Puzzle II
# Bit Substrings /problemset/task/2115
# CSES - Bit Substrings
# Reversal Sorting /problemset/task/2075
# CSES - Reversal Sorting
# Book Shop II /problemset/task/1159
# CSES - Book Shop II
# GCD Subsets /problemset/task/3161
# CSES - GCD Subsets
# Minimum Cost Pairs /problemset/task/3402
# CSES - Minimum Cost Pairs
# Same Sum Subsets /problemset/task/3425
# CSES - Same Sum Subsets
# Mex Grid Queries /problemset/task/1157
# CSES - Mex Grid Queries
# Maximum Building II /problemset/task/1148
# CSES - Maximum Building II
# Stick Divisions /problemset/task/1161
# CSES - Stick Divisions
# Stick Difference /problemset/task/3401
# CSES - Stick Difference
# Coding Company /problemset/task/1665
# CSES - Coding Company
# Two Stacks Sorting /problemset/task/2402
# CSES - Two Stacks Sorting

# %% [markdown]
# # Code forces Problem sheet

# %%
import requests
from bs4 import BeautifulSoup
import psycopg2
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import dotenv

headers = {
    "Content-Type": "application/json",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
}
dotenv.load_dotenv()  # This loads the .env file

embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

conn = psycopg2.connect(
    dbname="dsa_search",
    user="dsa_user",
    password="dsa_user",
    host="localhost",
    port="5432",
)

# Create a cursor
cur = conn.cursor()

insert_query = """
INSERT INTO dsa_questions_gemini (title, difficulty, topic, link, description, embedding)
VALUES (%s, %s, %s, %s, %s, %s)
"""

problemset = "https://atcoder.jp/contests/practice2/tasks/practice2_a"

res = requests.get(problemset, headers=headers)
soup = BeautifulSoup(res.text, "html.parser")
problems = soup.find_all("a", href=True)
print(problems)
for problem in problems:
    print(problem.text, problem.get("href"))  # type: ignore
# for i in range(8, len(problems)):
#     print(problems[i].text, problems[i].get("href"))  # type: ignore
#     url = f"https://cses.fi{problems[i].get('href')}"  # type: ignore
#     res = requests.get(url)
#     soup = BeautifulSoup(res.text, "html.parser")
#     title = soup.find("title").text  # type: ignore
#     description = soup.find("p").text  # type: ignore
#     link = url
#     difficulty = "Unknown"
#     topic = "Unknown"
#     embedding = embeddings.embed_query(description)
#     cur.execute(insert_query, (title, difficulty, topic, link, description, embedding))
#     print(title)

conn.commit()
cur.close()
conn.close()
# Out:
# [<a class="navbar-brand" href="/home"></a>, <a class="contest-title" href="/contests/practice2">AtCoder Library Practice Contest</a>, <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
# <img src="//img.atcoder.jp/assets/top/img/flag-lang/en.png"/> English <span class="caret"></span>
# </a>, <a href="/contests/practice2/tasks/practice2_a?lang=ja"><img src="//img.atcoder.jp/assets/top/img/flag-lang/ja.png"/> 日本語</a>, <a href="/contests/practice2/tasks/practice2_a?lang=en"><img src="//img.atcoder.jp/assets/top/img/flag-lang/en.png"/> English</a>, <a href="/register?continue=https%3A%2F%2Fatcoder.jp%2Fcontests%2Fpractice2%2Ftasks%2Fpractice2_a">Sign Up</a>, <a href="/login?continue=https%3A%2F%2Fatcoder.jp%2Fcontests%2Fpractice2%2Ftasks%2Fpractice2_a">Sign In</a>, <a href="http://www.timeanddate.com/worldclock/fixedtime.html?iso=20200907T2231&amp;p1=248" target="blank"><time class="fixtime fixtime-full">2020-09-07 22:31:51+0900</time></a>, <a href="http://www.timeanddate.com/worldclock/fixedtime.html?iso=30200907T2231&amp;p1=248" target="blank"><time class="fixtime fixtime-full">3020-09-07 22:31:51+0900</time></a>, <a href="/home">Back to Home</a>, <a href="/contests/practice2"><span aria-hidden="true" class="glyphicon glyphicon-home"></span> Top</a>, <a href="/contests/practice2/tasks"><span aria-hidden="true" class="glyphicon glyphicon-tasks"></span> Tasks</a>, <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button"><span aria-hidden="true" class="glyphicon glyphicon-list"></span> Results<span class="caret"></span></a>, <a href="/contests/practice2/submissions"><span aria-hidden="true" class="glyphicon glyphicon-globe"></span> All Submissions</a>, <a href="/contests/practice2/editorial"><span aria-hidden="true" class="glyphicon glyphicon-book"></span> Editorial</a>, <a href="javascript:void(0)" id="fix-cnvtb"><span aria-hidden="true" class="glyphicon glyphicon-pushpin"></span></a>, <a class="btn btn-default btn-sm" href="/contests/practice2/tasks/practice2_a/editorial">Editorial</a>, <a href="https://github.com/yosupo06/library-checker-problems" target="blank">Based on Library Checker (Unionfind) (APACHE LICENSE, V2.0)</a>, <a class="a2a_dd" href="https://www.addtoany.com/share"></a>, <a href="/contests/practice2/rules">Rule</a>, <a href="/contests/practice2/glossary">Glossary</a>, <a href="/tos">Terms of service</a>, <a href="/privacy">Privacy Policy</a>, <a href="/personal">Information Protection Policy</a>, <a href="/company">Company</a>, <a href="/faq">FAQ</a>, <a href="/contact">Contact</a>, <a href="http://atcoder.co.jp">AtCoder Inc.</a>]
#  /home
# AtCoder Library Practice Contest /contests/practice2
#
#  English
#  #
#  日本語 /contests/practice2/tasks/practice2_a?lang=ja
#  English /contests/practice2/tasks/practice2_a?lang=en
# Sign Up /register?continue=https%3A%2F%2Fatcoder.jp%2Fcontests%2Fpractice2%2Ftasks%2Fpractice2_a
# Sign In /login?continue=https%3A%2F%2Fatcoder.jp%2Fcontests%2Fpractice2%2Ftasks%2Fpractice2_a
# 2020-09-07 22:31:51+0900 http://www.timeanddate.com/worldclock/fixedtime.html?iso=20200907T2231&p1=248
# 3020-09-07 22:31:51+0900 http://www.timeanddate.com/worldclock/fixedtime.html?iso=30200907T2231&p1=248
# Back to Home /home
#  Top /contests/practice2
#  Tasks /contests/practice2/tasks
#  Results #
#  All Submissions /contests/practice2/submissions
#  Editorial /contests/practice2/editorial
#  javascript:void(0)
# Editorial /contests/practice2/tasks/practice2_a/editorial
# Based on Library Checker (Unionfind) (APACHE LICENSE, V2.0) https://github.com/yosupo06/library-checker-problems
#  https://www.addtoany.com/share
# Rule /contests/practice2/rules
# Glossary /contests/practice2/glossary
# Terms of service /tos
# Privacy Policy /privacy
# Information Protection Policy /personal
# Company /company
# FAQ /faq
# Contact /contact
# AtCoder Inc. http://atcoder.co.jp
